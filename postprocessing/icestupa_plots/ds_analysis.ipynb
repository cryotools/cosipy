# %%
import matplotlib
matplotlib.use("TkAgg")
import matplotlib.pyplot as plt
import os
import numpy as np
import xarray as xr
import numpy as np
import argparse
# %matplotlib inline

# %%
ds = xr.open_dataset("../../data/output/guttannen21.nc")
ds
# Out:
# <xarray.Dataset>
# Dimensions:                  (lat: 1, layer: 200, lon: 1, time: 4043)
# Coordinates:
#   * time                     (time) datetime64[ns] 2020-11-22T15:00:00 ... 20...
#   * lat                      (lat) float64 46.66
#   * lon                      (lon) float64 8.29
# Dimensions without coordinates: layer
# Data variables:
#     HGT                      (lat, lon) float64 ...
#     MASK                     (lat, lon) int64 ...
#     SLOPE                    (lat, lon) int64 ...
#     ASPECT                   (lat, lon) int64 ...
#     T2                       (time, lat, lon) float64 ...
#     RH2                      (time, lat, lon) float64 ...
#     U2                       (time, lat, lon) float64 ...
#     PRES                     (time, lat, lon) float64 ...
#     G                        (time, lat, lon) float64 ...
#     FDIF                     (time, lat, lon) float64 ...
#     RRR                      (time, lat, lon) float64 ...
# ...

# %%
ds.CONEHEIGHT.plot()
ds.CONERAD.plot()

# %%
ds.SWNET.plot()

# %%
ds.G.plot()

# %%
ds['LWNET'] = ds['LWin'] + ds['LWout']
ds.LWNET.plot()

# %%
ds.B.plot()

# %%
ds.Q.plot()

# %%
ds.Q.plot()

# %%
ds.LAYERS.max().values
# Out:
# array(100.)

# %%
ds["V"] = ds["TOTALHEIGHT"] * ds["CONEAREA"]
ds.V.plot()

# %%
ds.CONEVOL.plot()

# %%
ds.sel(layer=slice(80)).LAYER_RHO.plot()

# %%
ds.sel(layer=slice(100)).LAYER_T.plot()

# %%
ds.sel(layer=slice(60)).LAYER_HEIGHT.plot()

# %%
ds.isel(time=-24).LAYER_HEIGHT.plot()
